# %% [markdown]
# # Simple Steps to Train Your Neural Network
#
# - Step 1: Problem Definition
#     - Input $x$
#     - Output $y$
# - Step 2: Data Preparation
#     - Download and Formatting Data: torch.utils.data.Dataset, torch.utils.data.DataLoader
#     - Data Preprocessing: torchvision.transforms
# - Step 3: Model Architecture Design $f$
#     - torch.nn (Example: 2-Layer Neural Network)
# - Step 4: Loss Function Design $l(f(x), y)$
#     - torch.nn.functional (Example: CrossEntropyLoss)
# - Step 5: Optimizer Selection $\min l(f(x), y)$
#     - torch.optim (Example: mini-batch SGD)
# - Iteration:
#     - Step 7: Train the Neural Network
#         - Convergence, Loss curve
#     - Step 8: Validate the Model
#         - Train / Validation / Test
#     - Step 9: Evaluate the Model
#         - Accuracy
#     - Step 10: Model Tuning, Break if Got an Ideal Model
#         - Tuning hyperparameters

# %% [markdown]
# ## Step 1: Problem Definition

# %% [markdown]
# Image Classification:
#
# Input:
# - modality: image
# - datatype: uint8
# - shape:(224, 224, 3)
# - ranging: [0, 255]
#
# Output:
# - label: car, frog, ..., N classes
# - datatype: long
# - shape: (1,)
# - ranging: [0, N-1]

# %% [markdown]
# ## Step 2: Prepare the Data

# %% [markdown]
# recall that you have already used the `trainset` and `testset` in your assignment1:

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# 设置 matplotlib 显示格式
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0)  # 设置默认图像大小
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# CIFAR-10 数据集的下载和加载
transform = transforms.Compose(
    [transforms.ToTensor(),  # 转换为 Tensor
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]  # 归一化
)

# %%
from torch.utils.data import Dataset, DataLoader
trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
class OursDatasetwithTransforms(Dataset):
    def __init__(self, data, labels, transforms):
        """
        初始化数据集
        data: 输入数据，例如一个 NumPy 数组或 PyTorch 张量
        labels: 对应的标签
        """
        self.data = data
        self.labels = labels
        self.transforms = transforms

    def __len__(self):
        # 每个Dataset都必须写，返回数据集的大小
        return len(self.data)

    def __getitem__(self, idx):
        # 每个Dataset都必须写，获取指定索引idx的数据和标签
        sample = self.data[idx]
        label = self.labels[idx]
        sample = self.transforms(sample)
        return torch.tensor(sample, dtype=torch.float32), torch.tensor(label, dtype=torch.long)
        
transform = transforms.Compose(
    [transforms.ToTensor(),  # [0, 255], PIL Image / ndarray --> [0, 1], torch.tensor
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]  # 归一化, (input[channel] - mean[channel]) / std[channel]
)
traindata = trainset.data[:5000]
trainlabels = trainset.targets[:5000]
testdata = testset.data[:500]
testlabels = testset.targets[:500]

# 初始化自定义数据集
trainset = OursDatasetwithTransforms(traindata, trainlabels, transform)
testset = OursDatasetwithTransforms(testdata, testlabels, transform)
trainloader = DataLoader(trainset, batch_size=64, shuffle=False, drop_last=False)
testloader = DataLoader(testset, batch_size=64, shuffle=False, drop_last=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Step 3: Model Architecture Design

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Define a simple two-layer neural network
class TwoLayerNN(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_class):
        super(TwoLayerNN, self).__init__()
        # Flatten input 32*32*3 = 3072
        self.relu = nn.ReLU()  # Activation function
        self.fc1 = nn.Linear(input_dim, hidden_dim)  # First layer (input to hidden)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)  # Second layer (hidden to hidden)
        self.fc3 = nn.Linear(hidden_dim, num_class)  # Second layer (hidden to output)
    
    def forward(self, x):
        x = x.flatten(1)  # Flatten the image input
        x = self.fc1(x)  # First linear transformation
        x = self.relu(x)  # Apply ReLU activation
        x = self.fc2(x)  # Second linear transformation
        x = self.relu(x)  # Apply ReLU activation
        x = self.fc3(x)  # Second linear transformation
        return x

# Instantiate the model, loss function, and optimizer
input_dim = 32 * 32 * 3
hidden_dim = 100
num_class = 10
batch_size = 64
model = TwoLayerNN(input_dim, hidden_dim, num_class)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
print('Parameters: ', [name for name, param in model.named_parameters()])
print('Trainable Parameters: {:.3f}M'.format(sum([param.numel() for param in model.parameters()])/ 1024 / 1024))

input_test = torch.randn(batch_size, 32, 32, 3).to(device)

output = model(input_test)
print(output.shape)
# Out:
# Parameters:  ['fc1.weight', 'fc1.bias', 'fc2.weight', 'fc2.bias', 'fc3.weight', 'fc3.bias']
# Trainable Parameters: 0.304M
# torch.Size([64, 10])

# %% [markdown]
# ## An example to understand the concept of `model`, `training`, `loss`
#
#
# suppose we have 50 `data` with 1 dimention, we want to design a function $f$ (we will call it a `model` in the next few months), such that the curve of function `fits` the data

# %% [markdown]
# observing the data curve, we easily identify that it could be perfect if the function is a `sin/cos(x)`. Therefore we define the function as:
#
# $$f(x) = a\sin(bx+c) + d$$
#
# and simply define a L2 penalty, when the function does not predict well (we will call it `loss`):
#
# $$\min_{a,b,c,d}J(a,b,c,d)={(f(x) - y)^{2}}$$
#
# here, a,b,c,d are `parameters`

# %% [markdown]
# How to `optimize` the `parameters` in order to minimize the loss?
#
# Understanding Gradient descent via an Example:
#
# at first, a,b,c,d are randomly initialized, therefore the loss is large, suppose the parameter-loss curve be like (not the real curve of our loss):
# <img src="./GD.png">
#
# after optimizing the parameters through gradient descent, the function `diverges` in `local minima`
#
# Specifically, the gradient is the derivative of the function, i.e., $\frac{\delta f}{\delta a}$.
#
# Going along the direction of derivatives step by step, the gradient descent is formulated as:
#
# $$ w_i = w_i - \alpha\cdot \frac{\delta J(w)}{\delta w}, w=[a,b,c,d]$$
#
# the $\alpha$ is `learning rate`, determining the length that you update the parameters.
#
# Here we have N samples, therefore the formula is actually calculated as:
#
# $$ w_i = w_i - \alpha\cdot \frac{1}{N} \Sigma_{j=0}^{N} \frac{\delta J_j(w)}{\delta w}, w=[a,b,c,d]$$
#
#
# variants of gradient descent:
#
# we call the number of sample used in one update as `batch_size`
#
# - Batch GD: update parameter using the whole training data
# $$ w_i = w_i - \alpha\cdot \frac{1}{N} \Sigma_{j=0}^{N} \frac{\delta J_j(w)}{\delta w}, w=[a,b,c,d]$$
# - Stochastic GD: update parameter using only one sample
# $$ w_i = w_i - \alpha\cdot \frac{\delta J_j(w)}{\delta w}, w=[a,b,c,d]$$
# - Mini-Batch GD: update parameter using a mini batch of sample
# $$ w_i = w_i - \alpha\cdot \frac{1}{m} \Sigma_{j=0}^{m} \frac{\delta J_j(w)}{\delta w}, w=[a,b,c,d], m<N$$

# %%
criterion = nn.CrossEntropyLoss()  # Since it's a classification problem
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
# 训练模型
def train_model(num_epochs, step=100):
    train_loss_history = []
    test_loss_history = []
    print_interval = step  # 每隔多少step打印一次损失
    
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        step_loss = 0.0
        ############## TODO ##############
        # 遍历 trainloader
            # 把input和label放到对应device（cpu或cuda）
            
            # 清空优化器

            # 模型前向传播
            
            # 计算损失
            
            # 梯度反向传播

            # 利用优化器更新模型参数

            # 更新train loss

            # 每隔一定step打印和记录损失

        # 计算并记录每个epoch的训练损失
    
        # 评估模型
        evaluate_model(trainloader, 'train')
        test_loss = evaluate_model(testloader, 'test')
        
        print(f"Epoch [{epoch+1}/{num_epochs}] Completed, Avg Train Loss: {epoch_loss:.4f}, Test Loss: {test_loss:.4f}")

    return train_loss_history, test_loss_history

# 评估模型
def evaluate_model(loader, info):
    model.eval()
    total_loss = 0.0
    correct = 0
    total = 0
    # 阻止自动计算梯度
    with torch.no_grad():
        # 遍历loader

            # 把input和label放到对应device（cpu或cuda）
    
            # 前向传播
            
            # 计算loss
        
            # 把loss的值更新到total loss里
    
            # 计算预测的标签     
            
            # 计算预测正确的标签    
        
    avg_loss = total_loss / len(testloader)
    accuracy = 100 * correct / total

    print(f"{info} Accuracy: {accuracy:.2f}%")
    return avg_loss

# 绘制损失曲线
def plot_loss(train_loss, test_loss):
    plt.figure(figsize=(10, 5))
    plt.plot(train_loss, label='Train Loss')
    plt.plot(test_loss, label='Test Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Testing Loss')
    plt.show()

# 训练并评估模型
num_epochs = 60
train_loss, test_loss = train_model(num_epochs)

# 绘制损失曲线
plot_loss(train_loss, test_loss)
# Out:
# /tmp/ipykernel_1858230/1048525845.py:27: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(sample, dtype=torch.float32), torch.tensor(label, dtype=torch.long)
# train Accuracy: 31.54%
# test Accuracy: 29.20%
# Epoch [1/60] Completed, Avg Train Loss: 2.1114, Test Loss: 1.9461
# train Accuracy: 39.08%
# test Accuracy: 34.40%
# Epoch [2/60] Completed, Avg Train Loss: 1.8207, Test Loss: 1.8154
# train Accuracy: 42.80%
# test Accuracy: 36.60%
# Epoch [3/60] Completed, Avg Train Loss: 1.6696, Test Loss: 1.7609
# train Accuracy: 46.58%
# test Accuracy: 38.80%
# Epoch [4/60] Completed, Avg Train Loss: 1.5654, Test Loss: 1.7499
# train Accuracy: 50.82%
# test Accuracy: 39.00%
# Epoch [5/60] Completed, Avg Train Loss: 1.4678, Test Loss: 1.7527
# train Accuracy: 54.74%
# test Accuracy: 39.40%
# Epoch [6/60] Completed, Avg Train Loss: 1.3765, Test Loss: 1.7521
# train Accuracy: 58.16%
# test Accuracy: 38.80%
# Epoch [7/60] Completed, Avg Train Loss: 1.2872, Test Loss: 1.7645
# train Accuracy: 61.26%
# test Accuracy: 38.40%
# Epoch [8/60] Completed, Avg Train Loss: 1.1967, Test Loss: 1.7982
# train Accuracy: 63.96%
# test Accuracy: 38.60%
# Epoch [9/60] Completed, Avg Train Loss: 1.1027, Test Loss: 1.8535
# train Accuracy: 66.90%
# test Accuracy: 38.80%
# Epoch [10/60] Completed, Avg Train Loss: 1.0123, Test Loss: 1.9255
# train Accuracy: 68.92%
# test Accuracy: 39.20%
# Epoch [11/60] Completed, Avg Train Loss: 0.9226, Test Loss: 2.0276
# train Accuracy: 72.92%
# test Accuracy: 40.00%
# Epoch [12/60] Completed, Avg Train Loss: 0.8378, Test Loss: 2.1023
# train Accuracy: 74.86%
# test Accuracy: 39.20%
# Epoch [13/60] Completed, Avg Train Loss: 0.7511, Test Loss: 2.2000
# train Accuracy: 74.12%
# test Accuracy: 39.40%
# Epoch [14/60] Completed, Avg Train Loss: 0.6812, Test Loss: 2.4347
# train Accuracy: 72.90%
# test Accuracy: 36.00%
# Epoch [15/60] Completed, Avg Train Loss: 0.6473, Test Loss: 2.6680
# train Accuracy: 68.28%
# test Accuracy: 37.20%
# Epoch [16/60] Completed, Avg Train Loss: 0.6626, Test Loss: 2.9343
# train Accuracy: 65.84%
# test Accuracy: 38.60%
# Epoch [17/60] Completed, Avg Train Loss: 0.6941, Test Loss: 3.0416
# train Accuracy: 73.82%
# test Accuracy: 37.60%
# Epoch [18/60] Completed, Avg Train Loss: 0.6846, Test Loss: 2.9513
# train Accuracy: 77.02%
# test Accuracy: 37.60%
# Epoch [19/60] Completed, Avg Train Loss: 0.6885, Test Loss: 2.8138
# train Accuracy: 76.64%
# test Accuracy: 36.20%
# Epoch [20/60] Completed, Avg Train Loss: 0.5804, Test Loss: 2.9339
# train Accuracy: 77.08%
# test Accuracy: 37.20%
# Epoch [21/60] Completed, Avg Train Loss: 0.5110, Test Loss: 3.0340
# train Accuracy: 77.82%
# test Accuracy: 35.00%
# Epoch [22/60] Completed, Avg Train Loss: 0.4997, Test Loss: 3.1542
# train Accuracy: 78.54%
# test Accuracy: 33.60%
# Epoch [23/60] Completed, Avg Train Loss: 0.4746, Test Loss: 3.2646
# train Accuracy: 79.38%
# test Accuracy: 33.80%
# Epoch [24/60] Completed, Avg Train Loss: 0.4638, Test Loss: 3.3941
# train Accuracy: 76.80%
# test Accuracy: 33.60%
# Epoch [25/60] Completed, Avg Train Loss: 0.4129, Test Loss: 3.6773
# train Accuracy: 82.54%
# test Accuracy: 35.40%
# Epoch [26/60] Completed, Avg Train Loss: 0.3761, Test Loss: 3.4643
# train Accuracy: 84.66%
# test Accuracy: 35.00%
# Epoch [27/60] Completed, Avg Train Loss: 0.3107, Test Loss: 3.6585
# train Accuracy: 85.98%
# test Accuracy: 35.20%
# Epoch [28/60] Completed, Avg Train Loss: 0.2783, Test Loss: 3.7464
# train Accuracy: 81.60%
# test Accuracy: 32.20%
# Epoch [29/60] Completed, Avg Train Loss: 0.2410, Test Loss: 4.0311
# train Accuracy: 81.16%
# test Accuracy: 34.60%
# Epoch [30/60] Completed, Avg Train Loss: 0.2315, Test Loss: 4.3903
# train Accuracy: 85.22%
# test Accuracy: 33.00%
# Epoch [31/60] Completed, Avg Train Loss: 0.2290, Test Loss: 4.2310
# train Accuracy: 90.14%
# test Accuracy: 36.60%
# Epoch [32/60] Completed, Avg Train Loss: 0.2621, Test Loss: 4.0468
# train Accuracy: 87.60%
# test Accuracy: 36.40%
# Epoch [33/60] Completed, Avg Train Loss: 0.2358, Test Loss: 4.3534
# train Accuracy: 90.56%
# test Accuracy: 35.20%
# Epoch [34/60] Completed, Avg Train Loss: 0.2538, Test Loss: 4.1658
# train Accuracy: 89.94%
# test Accuracy: 35.00%
# Epoch [35/60] Completed, Avg Train Loss: 0.2501, Test Loss: 4.2426
# train Accuracy: 90.22%
# test Accuracy: 36.00%
# Epoch [36/60] Completed, Avg Train Loss: 0.2340, Test Loss: 4.4601
# train Accuracy: 91.84%
# test Accuracy: 38.60%
# Epoch [37/60] Completed, Avg Train Loss: 0.2249, Test Loss: 4.3831
# train Accuracy: 93.52%
# test Accuracy: 36.40%
# Epoch [38/60] Completed, Avg Train Loss: 0.1970, Test Loss: 4.3008
# train Accuracy: 94.04%
# test Accuracy: 38.80%
# Epoch [39/60] Completed, Avg Train Loss: 0.1636, Test Loss: 4.3277
# train Accuracy: 91.32%
# test Accuracy: 35.60%
# Epoch [40/60] Completed, Avg Train Loss: 0.1406, Test Loss: 4.9148
# train Accuracy: 93.42%
# test Accuracy: 38.20%
# Epoch [41/60] Completed, Avg Train Loss: 0.1454, Test Loss: 4.5672
# train Accuracy: 92.78%
# test Accuracy: 35.80%
# Epoch [42/60] Completed, Avg Train Loss: 0.1515, Test Loss: 4.5528
# train Accuracy: 93.80%
# test Accuracy: 35.20%
# Epoch [43/60] Completed, Avg Train Loss: 0.1428, Test Loss: 4.8588
# train Accuracy: 90.82%
# test Accuracy: 33.80%
# Epoch [44/60] Completed, Avg Train Loss: 0.1021, Test Loss: 4.9689
# train Accuracy: 93.58%
# test Accuracy: 34.00%
# Epoch [45/60] Completed, Avg Train Loss: 0.1185, Test Loss: 4.9714
# train Accuracy: 90.16%
# test Accuracy: 35.00%
# Epoch [46/60] Completed, Avg Train Loss: 0.1343, Test Loss: 5.2426
# train Accuracy: 94.80%
# test Accuracy: 37.20%
# Epoch [47/60] Completed, Avg Train Loss: 0.0960, Test Loss: 4.9004
# train Accuracy: 95.90%
# test Accuracy: 38.00%
# Epoch [48/60] Completed, Avg Train Loss: 0.0922, Test Loss: 4.9021
# train Accuracy: 93.22%
# test Accuracy: 37.20%
# Epoch [49/60] Completed, Avg Train Loss: 0.1094, Test Loss: 5.2236
# train Accuracy: 94.96%
# test Accuracy: 38.60%
# Epoch [50/60] Completed, Avg Train Loss: 0.0838, Test Loss: 5.0047
# train Accuracy: 96.26%
# test Accuracy: 38.80%
# Epoch [51/60] Completed, Avg Train Loss: 0.0769, Test Loss: 5.3230
# train Accuracy: 97.46%
# test Accuracy: 38.40%
# Epoch [52/60] Completed, Avg Train Loss: 0.0568, Test Loss: 5.1807
# train Accuracy: 98.76%
# test Accuracy: 38.40%
# Epoch [53/60] Completed, Avg Train Loss: 0.0425, Test Loss: 5.0626
# train Accuracy: 99.00%
# test Accuracy: 38.40%
# Epoch [54/60] Completed, Avg Train Loss: 0.0301, Test Loss: 5.0360
# train Accuracy: 98.54%
# test Accuracy: 39.40%
# Epoch [55/60] Completed, Avg Train Loss: 0.0215, Test Loss: 5.3009
# train Accuracy: 99.58%
# test Accuracy: 37.40%
# Epoch [56/60] Completed, Avg Train Loss: 0.0185, Test Loss: 5.3665
# train Accuracy: 100.00%
# test Accuracy: 38.60%
# Epoch [57/60] Completed, Avg Train Loss: 0.0091, Test Loss: 5.4228
# train Accuracy: 100.00%
# test Accuracy: 38.40%
# Epoch [58/60] Completed, Avg Train Loss: 0.0042, Test Loss: 5.4559
# train Accuracy: 100.00%
# test Accuracy: 39.00%
# Epoch [59/60] Completed, Avg Train Loss: 0.0031, Test Loss: 5.4841
# train Accuracy: 100.00%
# test Accuracy: 38.80%
# Epoch [60/60] Completed, Avg Train Loss: 0.0025, Test Loss: 5.5218

# %% [markdown]
# Impact of:
# - Larger model size (More hidden state each layer; More layers)
# - Different optimizer (e.g. torch.optim.Adam, torch.optim.AdamW)
# - Novel architecture (e.g., Dropout, BatchNormalization, etc.)
# - Weight initialization (e.g. xavier)
# - Novel loss / regularization (e.g. l2)
# - hyper-parameters (e.g. Batchsize, learning rate, etc.)

# %% [markdown]
# a playground by Google: https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=circle&regDataset=reg-gauss&learningRate=0.03&regularizationRate=0&noise=0&networkShape=5,2,2&seed=0.07966&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false
